// %%
%maven dev.langchain4j:langchain4j-open-ai:0.33.0

import dev.langchain4j.model.openai.OpenAiChatModel;
import dev.langchain4j.model.chat.ChatLanguageModel;

String apiKey = "AIzaSyDNsoTkxbTCpdpFMUsfcrFu3uo-YBVTc_M"; 

ChatLanguageModel model = OpenAiChatModel.builder()
    .apiKey(apiKey)
    .baseUrl("https://generativelanguage.googleapis.com/v1beta/openai/")
    .modelName("gemma-4-31b-it")
    .logRequests(true)
    .logResponses(true)
    .build();

String response = model.generate("How many moons does Jupiter have?");
System.out.println(response);
// Out:
// SLF4J: No SLF4J providers were found.
// SLF4J: Defaulting to no-operation (NOP) logger implementation
// SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
// <thought>*   Question: "How many moons does Jupiter have?"
//     *   Subject: Jupiter's moons.
//
//     *   Jupiter is known for having a vast number of moons.
//     *   The number changes as new, smaller moons are discovered.
//     *   *Current consensus (as of 2023/2024):* The International Astronomical Union (IAU) and NASA usually cite a specific number, but recent discoveries have pushed it higher.
//     *   *Key numbers:* 95 is the widely cited number following discoveries in 2023.
//
//     *   *Direct Answer:* Jupiter has 95 officially recognized moons.
//     *   *Context/Nuance:* Mention that this number can change as astronomers discover new ones.
//     *   *Highlighting the "Big Four":* Mention the Galilean moons (Io, Europa, Ganymede, Callisto) because they are the most famous and significant.
//
//     *   "Jupiter has 95 officially recognized moons." (Clear and direct).
//     *   "This number has increased in recent years as telescopes have become more powerful and discovered smaller, irregular moons." (Context).
//     *   "The most famous are the four large Galilean moons: Io, Europa, Ganymede, and Callisto." (Added value).</thought>Jupiter has **95 officially recognized moons**.
//
// This number has increased in recent years as astronomers have discovered many smaller, irregular moons orbiting the planet.
//
// The most famous of these are the four large **Galilean moons**, discovered by Galileo Galilei in 1610: **Io, Europa, Ganymede, and Callisto**. Ganymede is particularly notable for being the largest moon in our entire solar system.
